# %%
from si.data.dataset import Dataset
from si.linear_model.logistic_regression import LogisticRegression
from si.io.CSV import read_csv
from si.model_selection.cross_validate import cross_validate
from si.model_selection.grid_search import grid_search_cv
from si.model_selection.randomized_search import randomized_search_cv
from sklearn.preprocessing import StandardScaler
import numpy as np
import pandas as pd

# %%
data = read_csv("D:/Mestrado/2ano/1semestre/SIB/si/datasets/breast/breast-bin.data", ",", False, True)

data.X = StandardScaler().fit_transform(data.X)

# %%
model = LogisticRegression()
scores = cross_validate(model, data, cv=5, test_size=0.3)

#print(scores)
scores_dataframe = pd.DataFrame(scores)
print(scores_dataframe)
# Out:
#    seeds     train      test
# 0    374  0.969325  0.969325
# 1    866  0.965235  0.965235
# 2    913  0.973415  0.973415
# 3    833  0.963190  0.963190
# 4    439  0.967280  0.967280

# %%
model = LogisticRegression()

parameters = {"l2_penalty": [1, 10],
              "alpha": [0.001, 0.0001],
              "max_iter": [1000, 2000]}

scores = grid_search_cv(model, data, parameters, cv=3, test_size=0.3)

#print(scores)

for elem in scores:
    print("\n|\n")
    print("Parameters:\n-----------")
    print(elem["parameters"])
    print("\nScores:\n-------")
    print(pd.DataFrame({k:v for k,v in elem.items() if k!="parameters"}))
# Out:
# |
#
# Parameters:
# -----------
# {'l2_penalty': 1, 'alpha': 0.001, 'max_iter': 1000}
#
# Scores:
# -------
#    seeds     train      test
# 0    304  0.967280  0.967280
# 1    756  0.969325  0.969325
# 2    808  0.965235  0.965235
#
# |
#
# Parameters:
# -----------
# {'l2_penalty': 1, 'alpha': 0.001, 'max_iter': 2000}
#
# Scores:
# -------
#    seeds     train      test
# 0    968  0.963190  0.963190
# 1    155  0.965235  0.965235
# 2    473  0.969325  0.969325
#
# |
#
# Parameters:
# -----------
# {'l2_penalty': 1, 'alpha': 0.0001, 'max_iter': 1000}
#
# Scores:
# -------
#    seeds     train      test
# 0    195  0.965235  0.965235
# 1    111  0.965235  0.965235
# 2    897  0.983640  0.983640
#
# |
#
# Parameters:
# -----------
# {'l2_penalty': 1, 'alpha': 0.0001, 'max_iter': 2000}
#
# Scores:
# -------
#    seeds     train      test
# 0    756  0.969325  0.969325
# 1    808  0.965235  0.965235
# 2    968  0.963190  0.963190
#
# |
#
# Parameters:
# -----------
# {'l2_penalty': 10, 'alpha': 0.001, 'max_iter': 1000}
#
# Scores:
# -------
#    seeds     train      test
# 0    155  0.965235  0.965235
# 1    473  0.969325  0.969325
# 2    195  0.965235  0.965235
#
# |
#
# Parameters:
# -----------
# {'l2_penalty': 10, 'alpha': 0.001, 'max_iter': 2000}
#
# Scores:
# -------
#    seeds     train      test
# 0    111  0.967280  0.967280
# 1    897  0.983640  0.983640
# 2    756  0.969325  0.969325
#
# |
#
# Parameters:
# -----------
# {'l2_penalty': 10, 'alpha': 0.0001, 'max_iter': 1000}
#
# Scores:
# -------
#    seeds     train      test
# 0    808  0.965235  0.965235
# 1    968  0.963190  0.963190
# 2    155  0.965235  0.965235
#
# |
#
# Parameters:
# -----------
# {'l2_penalty': 10, 'alpha': 0.0001, 'max_iter': 2000}
#
# Scores:
# -------
#    seeds     train      test
# 0    473  0.969325  0.969325
# 1    195  0.965235  0.965235
# 2    111  0.965235  0.965235

# %%
model = LogisticRegression()

parameters = {"l2_penalty": np.linspace(1,10,10).astype(int),
              "alpha": np.linspace(0.001, 0.0001, 100),
              "max_iter": np.linspace(1000, 2000, 200).astype(int)}

scores = randomized_search_cv(model, data, parameters, cv=3, n_iter=10, test_size=0.3)

#print(scores)

for elem in scores:
    print("\n|\n")
    print("Parameters:\n-----------")
    print(elem["parameters"])
    print("\nScores:\n-------")
    print(pd.DataFrame({k:v for k,v in elem.items() if k!="parameters"}))
# Out:
# |
#
# Parameters:
# -----------
# {'l2_penalty': 2, 'alpha': 0.0002909090909090909, 'max_iter': 1859}
#
# Scores:
# -------
#    seeds    train     test
# 0    102  0.96728  0.96728
# 1    139  0.96728  0.96728
# 2    762  0.96319  0.96319
#
# |
#
# Parameters:
# -----------
# {'l2_penalty': 7, 'alpha': 0.00016363636363636363, 'max_iter': 1502}
#
# Scores:
# -------
#    seeds     train      test
# 0    635  0.965235  0.965235
# 1    932  0.963190  0.963190
# 2    967  0.971370  0.971370
#
# |
#
# Parameters:
# -----------
# {'l2_penalty': 3, 'alpha': 0.0007909090909090909, 'max_iter': 1618}
#
# Scores:
# -------
#    seeds     train      test
# 0    124  0.967280  0.967280
# 1    572  0.973415  0.973415
# 2     70  0.963190  0.963190
#
# |
#
# Parameters:
# -----------
# {'l2_penalty': 1, 'alpha': 0.0008818181818181819, 'max_iter': 1763}
#
# Scores:
# -------
#    seeds     train      test
# 0    363  0.965235  0.965235
# 1    333  0.965235  0.965235
# 2    545  0.965235  0.965235
#
# |
#
# Parameters:
# -----------
# {'l2_penalty': 2, 'alpha': 0.0006090909090909092, 'max_iter': 1125}
#
# Scores:
# -------
#    seeds    train     test
# 0    974  0.96728  0.96728
# 1    227  0.96728  0.96728
# 2    790  0.96319  0.96319
#
# |
#
# Parameters:
# -----------
# {'l2_penalty': 4, 'alpha': 0.0007363636363636363, 'max_iter': 1567}
#
# Scores:
# -------
#    seeds     train      test
# 0    164  0.961145  0.961145
# 1    930  0.973415  0.973415
# 2    776  0.967280  0.967280
#
# |
#
# Parameters:
# -----------
# {'l2_penalty': 9, 'alpha': 0.0006090909090909092, 'max_iter': 2000}
#
# Scores:
# -------
#    seeds     train      test
# 0     58  0.971370  0.971370
# 1    557  0.963190  0.963190
# 2    984  0.957055  0.957055
#
# |
#
# Parameters:
# -----------
# {'l2_penalty': 5, 'alpha': 0.00044545454545454543, 'max_iter': 1788}
#
# Scores:
# -------
#    seeds     train      test
# 0    170  0.969325  0.969325
# 1    478  0.961145  0.961145
# 2    631  0.961145  0.961145
#
# |
#
# Parameters:
# -----------
# {'l2_penalty': 1, 'alpha': 0.0007454545454545455, 'max_iter': 1693}
#
# Scores:
# -------
#    seeds     train      test
# 0    636  0.971370  0.971370
# 1    599  0.971370  0.971370
# 2     68  0.969325  0.969325
#
# |
#
# Parameters:
# -----------
# {'l2_penalty': 4, 'alpha': 0.0003363636363636364, 'max_iter': 1286}
#
# Scores:
# -------
#    seeds     train      test
# 0    813  0.955010  0.955010
# 1     27  0.965235  0.965235
# 2    779  0.967280  0.967280
